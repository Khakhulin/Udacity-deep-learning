# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'anarchism', 'a', 'originated', 'originated', 'as', 'of', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.563187
# Nearest to four: lowe, doctrines, bounded, nsh, failure, manager, vastly, bactria,
# Nearest to of: footage, secularism, excreted, clin, uncompressed, maclennan, mystical, rhetoric,
# Nearest to been: valentine, prerequisites, revoked, disparaged, lavender, dewitt, curbed, warranty,
# Nearest to nine: crucified, suisse, muon, forgiven, friendly, agnetha, seventh, sulfate,
# Nearest to time: freed, fauna, loti, sour, conf, consists, saleh, domine,
# Nearest to during: lionel, identify, yours, cretaceous, christendom, meuse, harsher, capybara,
# Nearest to by: deeply, jarry, tiglath, brentwood, line, villa, tata, myrrh,
# Nearest to people: tricyclic, deansgate, panini, listed, punishes, facilitates, callisthenes, anthemius,
# Nearest to had: apollinaris, illinois, xm, resilience, theorize, finding, kilo, faroese,
# Nearest to a: spousal, consecutively, abolitionist, merseyside, adolescents, excitation, clashed, millicent,
# Nearest to d: partitioned, wordsworth, preclear, biographies, cisneros, hotels, plundering, synthesizing,
# Nearest to many: iceman, suitor, coquitlam, motorists, bidder, freshness, betrays, officer,
# Nearest to with: slaughters, nonaggression, uncontrolled, elgar, zinc, lyell, bags, lover,
# Nearest to and: yeho, groupings, imr, shook, phenols, mordant, tiberias, wildcats,
# Nearest to their: sandworm, vince, friz, coloration, wolfhound, fathers, extolling, geothermal,
# Nearest to will: pursued, pechenegs, amplitude, pala, zodiac, kodak, nudity, cubes,
# Average loss at step 2000: 4.367622
# Average loss at step 4000: 3.867877
# Average loss at step 6000: 3.785023
# Average loss at step 8000: 3.689520
# Average loss at step 10000: 3.610437
# Nearest to four: six, five, eight, three, seven, two, nine, zero,
# Nearest to of: in, at, for, discerning, szabo, interfere, during, from,
# Nearest to been: reichenbach, valentine, resolved, hive, originally, solos, fanatics, mocked,
# Nearest to nine: eight, seven, six, five, zero, three, four, two,
# Nearest to time: tricyclic, consists, loti, conf, cuyahoga, statutory, audition, use,
# Nearest to during: at, cretaceous, identify, souk, of, tangle, dharmas, yours,
# Nearest to by: was, be, in, on, with, as, tarkovsky, orthogonal,
# Nearest to people: tricyclic, punishes, deansgate, listed, ends, showa, vipers, millimetre,
# Nearest to had: has, have, was, apollinaris, then, henley, tenochtitl, hasbro,
# Nearest to a: the, brutus, bok, this, checked, bachman, oscillation, inefficiencies,
# Nearest to d: heights, sailing, b, senex, biographies, closest, clauses, cochran,
# Nearest to many: some, officer, camacho, standby, gottwald, hanyu, heck, chesterfield,
# Nearest to with: in, by, for, leiden, bute, after, zinc, notting,
# Nearest to and: or, who, in, american, which, but, although, he,
# Nearest to their: his, her, the, its, dorff, education, pinnacles, vince,
# Nearest to will: could, would, pursued, must, can, eeeeee, zodiac, went,
# Average loss at step 12000: 3.610068
# Average loss at step 14000: 3.572997
# Average loss at step 16000: 3.412854
# Average loss at step 18000: 3.455704
# Average loss at step 20000: 3.540340
# Nearest to four: six, five, eight, three, seven, nine, two, zero,
# Nearest to of: for, in, main, leptons, pico, deference, from, studd,
# Nearest to been: be, become, originally, was, resolved, had, reichenbach, valentine,
# Nearest to nine: eight, six, seven, four, five, zero, three, two,
# Nearest to time: tricyclic, cuyahoga, vote, date, statutory, consists, loti, sour,
# Nearest to during: at, cretaceous, made, souk, apprehend, on, in, heterosexuals,
# Nearest to by: be, were, in, for, byng, orestes, was, unscr,
# Nearest to people: vipers, ferguson, listed, you, inequalities, want, punishes, deansgate,
# Nearest to had: has, have, was, were, apollinaris, been, shows, having,
# Nearest to a: the, bok, this, linen, graceful, no, oddie, backslash,
# Nearest to d: b, biographies, nemo, heights, german, fb, coney, denning,
# Nearest to many: some, several, these, all, other, officer, various, numerous,
# Nearest to with: in, between, after, slaughters, instigated, or, svenska, without,
# Nearest to and: or, but, while, in, at, under, from, demeter,
# Nearest to their: his, its, the, her, some, them, these, scant,
# Nearest to will: would, can, could, may, must, to, pursued, eeeeee,
# Average loss at step 22000: 3.509313
# Average loss at step 24000: 3.488823
# Average loss at step 26000: 3.485415
# Average loss at step 28000: 3.482395
# Average loss at step 30000: 3.504838
# Nearest to four: five, six, three, seven, eight, two, nine, zero,
# Nearest to of: in, and, from, bye, for, including, paradiso, austronesian,
# Nearest to been: become, be, was, already, were, vivaldi, celebes, hive,
# Nearest to nine: eight, seven, six, five, four, three, zero, one,
# Nearest to time: period, date, cuyahoga, vote, sour, story, tricyclic, statutory,
# Nearest to during: at, in, from, cretaceous, after, until, under, souk,
# Nearest to by: in, unscr, melatonin, nonpartisan, were, was, as, exarchate,
# Nearest to people: countries, punishes, want, ferguson, listed, you, those, inequalities,
# Nearest to had: has, have, was, were, shows, apollinaris, having, gave,
# Nearest to a: the, no, any, grows, graceful, wagers, hazlitt, this,
# Nearest to d: b, nemo, everly, denning, german, crowther, phenomenology, ngo,
# Nearest to many: some, several, these, all, various, the, numerous, phage,
# Nearest to with: between, against, bute, in, without, after, by, outweighs,
# Nearest to and: or, but, of, in, who, annabel, hate, wherein,
# Nearest to their: his, its, the, her, some, these, our, scant,
# Nearest to will: would, can, could, may, must, should, shall, neutral,
# Average loss at step 32000: 3.498383
# Average loss at step 34000: 3.497783
# Average loss at step 36000: 3.458512
# Average loss at step 38000: 3.303670
# Average loss at step 40000: 3.431921
# Nearest to four: six, five, three, seven, eight, two, nine, one,
# Nearest to of: in, authenticity, humoral, for, from, mtp, consulting, following,
# Nearest to been: become, be, was, were, already, celebes, had, originally,
# Nearest to nine: eight, seven, six, five, zero, four, three, births,
# Nearest to time: tricyclic, period, day, story, mattered, massimo, plotline, shakes,
# Nearest to during: at, in, after, until, before, spoiler, throughout, since,
# Nearest to by: impiety, kathleen, be, as, with, villa, when, was,
# Nearest to people: those, countries, deansgate, amplification, anthemius, ransom, trot, groups,
# Nearest to had: has, have, was, were, having, marcomanni, since, been,
# Nearest to a: the, another, or, workmen, no, cynic, getting, graceful,
# Nearest to d: b, e, denning, phenomenology, innermost, britannicus, worst, chopping,
# Nearest to many: some, several, these, various, those, numerous, were, camacho,
# Nearest to with: between, in, against, zinc, including, after, maxims, by,
# Nearest to and: or, but, celsius, including, assembles, quayle, while, in,
# Nearest to their: its, his, her, the, our, some, these, any,
# Nearest to will: can, would, could, may, must, should, might, cannot,
# Average loss at step 42000: 3.435882
# Average loss at step 44000: 3.452414
# Average loss at step 46000: 3.452389
# Average loss at step 48000: 3.358215
# Average loss at step 50000: 3.388764
# Nearest to four: six, five, three, seven, eight, nine, two, zero,
# Nearest to of: in, rial, studd, universidad, nm, and, brunner, mere,
# Nearest to been: become, be, already, were, had, originally, celebes, vivaldi,
# Nearest to nine: eight, seven, six, four, five, zero, three, two,
# Nearest to time: day, period, way, tricyclic, story, year, mattered, pillaging,
# Nearest to during: in, at, after, when, before, throughout, following, however,
# Nearest to by: through, after, while, into, byng, yong, as, during,
# Nearest to people: countries, children, men, ransom, offense, those, jews, twenty,
# Nearest to had: has, have, was, were, having, marcomanni, proclus, been,
# Nearest to a: the, any, another, hazlitt, no, brutus, cognomen, linen,
# Nearest to d: b, e, innermost, phenomenology, r, waning, denning, fb,
# Nearest to many: some, several, these, those, various, most, numerous, such,
# Nearest to with: between, against, slaughters, after, magnetometer, maxims, including, eyewitness,
# Nearest to and: or, including, but, while, ligaments, however, although, corgi,
# Nearest to their: its, his, her, our, the, these, them, championing,
# Nearest to will: would, can, could, may, must, should, might, shall,
# Average loss at step 52000: 3.436439
# Average loss at step 54000: 3.422066
# Average loss at step 56000: 3.443481
# Average loss at step 58000: 3.396137
# Average loss at step 60000: 3.394553
# Nearest to four: five, six, eight, seven, three, nine, zero, two,
# Nearest to of: in, for, reproducible, same, taped, like, brunner, opry,
# Nearest to been: become, be, already, were, roadmap, previously, had, originally,
# Nearest to nine: eight, six, seven, five, four, zero, three, one,
# Nearest to time: period, tricyclic, way, mattered, day, year, pillaging, case,
# Nearest to during: following, after, in, before, throughout, although, under, at,
# Nearest to by: through, with, melatonin, nonpartisan, be, villa, during, byng,
# Nearest to people: countries, those, children, americans, christians, jews, men, twenty,
# Nearest to had: has, have, was, were, having, received, electrolytic, proclus,
# Nearest to a: the, any, another, checked, salman, brutus, no, this,
# Nearest to d: b, e, waning, fb, denning, h, r, innermost,
# Nearest to many: some, several, these, various, most, those, such, all,
# Nearest to with: between, including, slaughters, by, although, in, outweighs, against,
# Nearest to and: or, but, while, although, than, including, phenols, anchoring,
# Nearest to their: its, his, her, our, the, my, some, these,
# Nearest to will: would, could, can, may, must, should, might, cannot,
# Average loss at step 62000: 3.242397
# Average loss at step 64000: 3.258638
# Average loss at step 66000: 3.405057
# Average loss at step 68000: 3.395055
# Average loss at step 70000: 3.361819
# Nearest to four: five, six, three, seven, eight, zero, two, nine,
# Nearest to of: including, leptons, and, in, or, mere, criminality, original,
# Nearest to been: become, be, already, were, was, previously, vivaldi, had,
# Nearest to nine: eight, six, seven, five, four, zero, three, one,
# Nearest to time: mattered, tricyclic, period, story, daggers, case, day, pillaging,
# Nearest to during: after, in, throughout, following, before, at, spoiler, despite,
# Nearest to by: through, be, melatonin, nonpartisan, in, with, jarry, was,
# Nearest to people: countries, those, men, children, individuals, jews, tourists, theta,
# Nearest to had: has, have, was, were, having, became, electrolytic, cub,
# Nearest to a: another, the, planar, this, bok, graceful, any, cognomen,
# Nearest to d: b, e, r, h, phenomenology, webmineral, innermost, f,
# Nearest to many: some, several, these, various, most, those, all, numerous,
# Nearest to with: between, slaughters, against, untrained, by, dipole, bentham, in,
# Nearest to and: or, but, while, of, see, including, like, countable,
# Nearest to their: its, his, her, the, our, my, some, your,
# Nearest to will: would, can, could, may, must, should, might, cannot,
# Average loss at step 72000: 3.376244
# Average loss at step 74000: 3.350436
# Average loss at step 76000: 3.324938
# Average loss at step 78000: 3.348575
# Average loss at step 80000: 3.378562
# Nearest to four: five, six, eight, seven, three, nine, two, zero,
# Nearest to of: including, in, discerning, studd, dakota, lupin, from, interdict,
# Nearest to been: become, be, already, were, was, previously, had, being,
# Nearest to nine: eight, seven, six, four, five, zero, three, births,
# Nearest to time: day, mattered, story, year, period, pillaging, cuar, tricyclic,
# Nearest to during: after, in, throughout, before, following, while, despite, although,
# Nearest to by: melatonin, through, augmenting, nonpartisan, argumentum, weavers, yong, byng,
# Nearest to people: children, men, jews, those, countries, individuals, tourists, man,
# Nearest to had: has, have, was, having, were, became, received, been,
# Nearest to a: another, the, every, verrocchio, planar, any, hazlitt, cracking,
# Nearest to d: b, e, h, l, r, p, webmineral, innermost,
# Nearest to many: several, some, various, these, numerous, those, most, both,
# Nearest to with: between, untrained, into, slaughters, in, through, including, against,
# Nearest to and: or, including, while, but, resonate, punts, alamanni, ricci,
# Nearest to their: its, his, her, our, my, the, your, both,
# Nearest to will: would, can, could, may, must, should, might, cannot,
# Average loss at step 82000: 3.412102
# Average loss at step 84000: 3.413235
# Average loss at step 86000: 3.389693
# Average loss at step 88000: 3.351674
# Average loss at step 90000: 3.372042
# Nearest to four: seven, five, eight, six, three, nine, two, zero,
# Nearest to of: including, leptons, in, for, discerning, lupin, during, studd,
# Nearest to been: become, be, already, previously, was, were, being, celebes,
# Nearest to nine: eight, seven, six, five, four, zero, three, two,
# Nearest to time: mattered, story, day, futurist, pillaging, feat, corel, sabha,
# Nearest to during: after, in, throughout, while, before, despite, following, although,
# Nearest to by: with, through, when, nonpartisan, during, yong, under, byng,
# Nearest to people: children, men, individuals, americans, man, jews, women, christians,
# Nearest to had: has, have, having, was, were, since, yacc, continued,
# Nearest to a: any, another, the, graceful, rescuing, bachman, hazlitt, every,
# Nearest to d: b, h, f, e, webmineral, zero, fb, frac,
# Nearest to many: several, some, various, these, those, numerous, most, all,
# Nearest to with: between, in, by, dipole, against, through, including, and,
# Nearest to and: or, but, while, including, jadwiga, ligaments, annabel, with,
# Nearest to their: its, his, her, our, my, the, your, them,
# Nearest to will: would, could, can, may, must, should, might, cannot,
# Average loss at step 92000: 3.400629
# Average loss at step 94000: 3.258883
# Average loss at step 96000: 3.358795
# Average loss at step 98000: 3.245401
# Average loss at step 100000: 3.359602
# Nearest to four: seven, six, five, eight, three, two, nine, zero,
# Nearest to of: including, msn, in, leptons, bye, and, original, whose,
# Nearest to been: become, be, already, previously, was, remained, had, celebes,
# Nearest to nine: eight, seven, six, four, five, zero, three, one,
# Nearest to time: mattered, cuar, bootp, sunshine, affray, day, year, question,
# Nearest to during: after, throughout, in, following, although, before, despite, at,
# Nearest to by: without, when, through, be, yong, blanket, byng, nonpartisan,
# Nearest to people: children, individuals, women, jews, players, americans, christians, men,
# Nearest to had: has, have, was, having, since, were, traditionalist, is,
# Nearest to a: another, the, any, verrocchio, hazlitt, thereof, planar, bachman,
# Nearest to d: b, phenomenology, h, l, charlie, huguenot, fb, repeats,
# Nearest to many: several, some, these, various, numerous, those, few, all,
# Nearest to with: between, including, eyewitness, romani, when, hickory, by, slaughters,
# Nearest to and: or, but, while, jadwiga, although, when, including, like,
# Nearest to their: its, his, our, her, your, the, my, whose,
# Nearest to will: would, could, can, should, must, may, might, cannot,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0
def generate_batch(batch_size, cbow_window):
    global data_index
    span = 2 * cbow_window + 1
    batch = np.ndarray(shape=(batch_size, span - 1), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32) 
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size):
        batch[i] = list(buffer)[:-1]
        target = cbow_window
        batch[i][target] = buffer[span - 1]
        labels[i] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:16]])


data_index = 0
batch, labels = generate_batch(batch_size=4, cbow_window = 2)

print([[reverse_dictionary[w] for w in w_list] for w_list  in batch])
print([reverse_dictionary[l] for l in labels.reshape(4)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the']
# [['anarchism', 'originated', 'term', 'a'], ['originated', 'as', 'of', 'term'], ['as', 'a', 'abuse', 'of'], ['a', 'term', 'first', 'abuse']]
# ['as', 'a', 'term', 'of']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
cbow_window = 2 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size, 2 * cbow_window ])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
    # Model.
    # Look up embeddings for inputs.
    embed0 = tf.nn.embedding_lookup(embeddings, train_dataset[:, 0])
    embed1 = tf.nn.embedding_lookup(embeddings, train_dataset[:, 1])
    embeds = embed0 + embed1
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embeds,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

    # Optimizer.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
        normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001
with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(batch_size, cbow_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
    # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.131268
# Nearest to one: richness, compounded, cabo, michel, yup, curtail, bioterrorism, sclerosis,
# Nearest to see: indirectly, soon, elkhart, inadequacy, ilo, implantation, schelling, spamming,
# Nearest to new: patriarchates, compromised, turned, reject, la, maoist, enthalpy, mestizos,
# Nearest to of: sotho, xc, peaks, cars, personifications, triumphantly, courtly, ablation,
# Nearest to people: threw, duration, proclaimed, liza, gygax, mutagenesis, wasting, announced,
# Nearest to d: ascribe, sgt, ekaterina, satrap, sixties, abm, elaborately, eater,
# Nearest to on: parabolic, taurus, realisation, overpowered, wanna, haze, loophole, theodoret,
# Nearest to his: deceit, amc, locarno, nurses, farrar, chico, nelly, rampage,
# Nearest to into: melvin, etonians, spacesuit, complimentary, workplace, axels, maid, admissions,
# Nearest to most: acutely, constituent, biologists, refit, endure, trois, individual, imi,
# Nearest to known: plate, algol, francium, iqaluit, reynolds, repetitions, alphabetically, termites,
# Nearest to at: generators, trousers, creighton, yag, climbing, guayaquil, cervix, write,
# Nearest to had: elmo, depressants, kendall, radii, ung, neodymium, cyclic, terminus,
# Nearest to while: squeeze, mclaughlin, brenda, cancel, earp, conserved, manichaeism, patti,
# Nearest to american: antikythera, daewoo, synapses, mentha, opium, amortized, jersey, strived,
# Nearest to by: incrimination, throwers, unbounded, socket, pantheistic, holes, corrected, satavahana,
# Average loss at step 2000: 4.319703
# Average loss at step 4000: 3.768174
# Average loss at step 6000: 3.672928
# Average loss at step 8000: 3.592501
# Average loss at step 10000: 3.601658
# Nearest to one: nine, six, eight, seven, zero, five, four, two,
# Nearest to see: despatch, clinically, elkhart, phonemic, garde, spamming, chow, minimal,
# Nearest to new: global, arable, patriarchates, political, faint, torus, dynamic, cisc,
# Nearest to of: in, and, from, on, with, into, for, by,
# Nearest to people: spirituals, bordering, lamas, fayyum, bentsen, mmix, liza, slurred,
# Nearest to d: ascribe, satrap, eater, abm, sgt, n, sixties, bowels,
# Nearest to on: of, from, in, with, isothermal, into, for, following,
# Nearest to his: s, her, their, its, gianfranco, lifestyles, lawmakers, neuralgia,
# Nearest to into: of, in, from, isao, on, melvin, with, demeaning,
# Nearest to most: more, other, some, many, claimants, acutely, trois, hamdi,
# Nearest to known: such, plate, moli, ashe, informally, monomers, served, quarto,
# Nearest to at: from, of, burghs, inequalities, during, sampler, popping, to,
# Nearest to had: has, have, was, radii, were, having, is, with,
# Nearest to while: button, fujimori, patti, brenda, with, jaime, standoff, superseded,
# Nearest to american: antikythera, amortized, british, jersey, escap, reactions, meaningful, transposing,
# Nearest to by: with, of, for, including, among, consideration, from, ivies,
# Average loss at step 12000: 3.434111
# Average loss at step 14000: 3.304636
# Average loss at step 16000: 3.353964
# Average loss at step 18000: 3.457053
# Average loss at step 20000: 3.325565
# Nearest to one: eight, nine, seven, three, two, four, gutrune, five,
# Nearest to see: clinically, britannicus, honed, despatch, phonemic, tabular, garde, chow,
# Nearest to new: overfishing, weizenbaum, faint, kingfishers, osi, kinsman, geometer, papen,
# Nearest to of: between, from, into, for, with, in, including, called,
# Nearest to people: fayyum, spirituals, we, they, naci, those, bentsen, others,
# Nearest to d: b, sgt, isbn, ascribe, dvds, lovers, november, skipped,
# Nearest to on: from, into, with, around, following, between, in, of,
# Nearest to his: her, s, their, its, my, whose, negotiate, illicit,
# Nearest to into: with, of, through, from, in, on, within, selim,
# Nearest to most: some, many, more, several, other, number, claimants, all,
# Nearest to known: such, referred, well, served, ashe, moli, bode, tart,
# Nearest to at: from, wmap, around, over, during, within, antietam, popping,
# Nearest to had: has, have, having, with, was, radii, were, hutu,
# Nearest to while: fujimori, but, button, squeeze, patti, razor, malaya, qaddafi,
# Nearest to american: british, german, english, french, japanese, scottish, australian, canadian,
# Nearest to by: with, including, like, against, from, nootka, of, vocalist,
# Average loss at step 22000: 3.375882
# Average loss at step 24000: 3.419701
# Average loss at step 26000: 3.326689
# Average loss at step 28000: 3.305402
# Average loss at step 30000: 3.298418
# Nearest to one: eight, nine, seven, three, four, six, five, two,
# Nearest to see: clinically, britannicus, tabular, micah, schelling, traumas, garde, phonemic,
# Nearest to new: global, kingfishers, overfishing, guerre, weizenbaum, cisc, faint, codata,
# Nearest to of: from, into, between, called, in, with, include, around,
# Nearest to people: we, those, others, you, scholarship, man, u, severly,
# Nearest to d: b, nine, five, n, isbn, six, repertory, p,
# Nearest to on: from, cutoff, of, in, along, following, isothermal, across,
# Nearest to his: her, s, their, its, my, whose, our, him,
# Nearest to into: in, of, through, from, within, with, called, between,
# Nearest to most: many, some, more, other, very, mulroney, several, walloon,
# Nearest to known: such, referred, used, well, described, regarded, served, emerged,
# Nearest to at: from, around, kinder, during, park, wmap, near, cane,
# Nearest to had: have, has, having, was, were, radii, iquique, is,
# Nearest to while: among, although, where, button, razor, when, though, however,
# Nearest to american: british, canadian, japanese, german, english, french, russian, swedish,
# Nearest to by: including, like, against, with, from, nootka, include, through,
# Average loss at step 32000: 3.185035
# Average loss at step 34000: 3.253824
# Average loss at step 36000: 3.258301
# Average loss at step 38000: 3.257167
# Average loss at step 40000: 3.287709
# Nearest to one: seven, nine, eight, four, six, two, three, macduff,
# Nearest to see: britannicus, clinically, phonemic, tipu, schelling, disconnect, micah, achievement,
# Nearest to new: overfishing, weizenbaum, cisc, guerre, osi, global, kingfishers, infecting,
# Nearest to of: between, including, around, about, from, within, through, for,
# Nearest to people: others, those, we, you, students, geologic, women, man,
# Nearest to d: b, f, n, ascribe, dvds, sliced, dib, repertory,
# Nearest to on: from, cutoff, through, between, in, isothermal, across, off,
# Nearest to his: her, s, their, whose, my, its, him, our,
# Nearest to into: through, from, within, in, between, of, contains, like,
# Nearest to most: many, some, more, several, number, less, all, other,
# Nearest to known: such, referred, regarded, emerged, well, served, same, used,
# Nearest to at: from, sampler, near, around, kinder, over, wmap, of,
# Nearest to had: has, have, having, was, were, iquique, requires, kindling,
# Nearest to while: although, however, but, though, among, where, razor, when,
# Nearest to american: canadian, british, swedish, professional, australian, japanese, scottish, french,
# Nearest to by: including, against, like, include, with, from, zola, nootka,
# Average loss at step 42000: 3.243925
# Average loss at step 44000: 3.158746
# Average loss at step 46000: 3.255183
# Average loss at step 48000: 3.221785
# Average loss at step 50000: 3.227797
# Nearest to one: nine, seven, six, kampuchea, eight, five, lancet, consists,
# Nearest to see: schelling, garde, britannicus, tipu, elkhart, sleeping, honed, indochina,
# Nearest to new: nordic, geometer, strachey, codata, dynamic, weizenbaum, old, current,
# Nearest to of: against, including, for, include, with, between, into, from,
# Nearest to people: those, others, man, players, students, americans, we, woman,
# Nearest to d: b, n, f, natura, ascribe, const, r, mixolydian,
# Nearest to on: from, including, with, off, through, of, in, near,
# Nearest to his: her, s, their, my, whose, its, him, your,
# Nearest to into: through, in, from, of, within, between, with, using,
# Nearest to most: many, some, more, several, other, number, less, list,
# Nearest to known: such, well, referred, emerged, regarded, same, far, famous,
# Nearest to at: from, near, around, during, reached, over, sampler, kinder,
# Nearest to had: has, having, have, were, was, iquique, yet, radii,
# Nearest to while: although, among, when, where, but, however, though, by,
# Nearest to american: professional, canadian, national, swedish, japanese, australian, british, scottish,
# Nearest to by: including, include, with, zola, against, like, while, from,
# Average loss at step 52000: 3.242491
# Average loss at step 54000: 3.198454
# Average loss at step 56000: 3.042349
# Average loss at step 58000: 3.208690
# Average loss at step 60000: 3.184844
# Nearest to one: eight, nine, four, seven, feathered, circa, kampuchea, monophysites,
# Nearest to see: tipu, garde, britannicus, elkhart, domineering, schwenkfeld, schelling, despatch,
# Nearest to new: old, nordic, overfishing, guerre, weizenbaum, loco, kuril, specialized,
# Nearest to of: between, with, in, through, within, called, include, against,
# Nearest to people: those, women, others, person, men, man, students, americans,
# Nearest to d: b, ascribe, f, clearing, deployable, r, sgt, mixolydian,
# Nearest to on: through, from, cutoff, across, about, between, isothermal, of,
# Nearest to his: her, s, their, my, whose, its, our, your,
# Nearest to into: through, in, within, create, between, of, includes, produces,
# Nearest to most: more, some, many, particularly, less, several, judson, highly,
# Nearest to known: such, well, referred, same, regarded, emerged, seen, far,
# Nearest to at: near, from, around, sampler, boles, reached, diaconate, multiplayer,
# Nearest to had: having, has, have, was, yet, requires, were, iquique,
# Nearest to while: although, among, though, however, but, where, when, button,
# Nearest to american: professional, australian, european, british, canadian, ets, scottish, asian,
# Nearest to by: include, including, against, with, through, like, from, of,
# Average loss at step 62000: 3.161809
# Average loss at step 64000: 3.194228
# Average loss at step 66000: 3.225199
# Average loss at step 68000: 3.190144
# Average loss at step 70000: 3.199625
# Nearest to one: nine, isbn, seven, lancet, eight, four, every, six,
# Nearest to see: schelling, tipu, garde, chittagong, called, elkhart, azteca, missy,
# Nearest to new: old, overfishing, kuril, weizenbaum, mackenzie, paradoxical, flanagan, nordic,
# Nearest to of: between, for, with, about, including, include, against, that,
# Nearest to people: women, others, those, man, men, students, person, children,
# Nearest to d: b, f, ascribe, const, n, c, tanker, sgt,
# Nearest to on: from, across, through, cutoff, upon, regarding, of, about,
# Nearest to his: her, s, their, my, whose, its, your, him,
# Nearest to into: through, in, within, between, from, with, create, of,
# Nearest to most: more, some, many, list, particularly, several, less, all,
# Nearest to known: such, referred, well, same, regarded, emerged, perceived, seen,
# Nearest to at: from, near, around, towards, wmap, reached, markka, multiplayer,
# Nearest to had: having, has, have, were, yet, was, could, radii,
# Nearest to while: although, but, though, when, among, where, however, thus,
# Nearest to american: australian, european, professional, canadian, german, national, japanese, french,
# Nearest to by: include, including, from, with, against, through, nootka, without,
# Average loss at step 72000: 3.137549
# Average loss at step 74000: 3.117701
# Average loss at step 76000: 3.173004
# Average loss at step 78000: 3.163874
# Average loss at step 80000: 3.053675
# Nearest to one: eight, nine, seven, two, five, six, lancet, kampuchea,
# Nearest to see: tipu, elkhart, britannicus, schelling, chittagong, references, fv, despatch,
# Nearest to new: overfishing, kuril, tangled, guerre, old, geometer, polka, earlier,
# Nearest to of: for, include, including, from, in, within, between, through,
# Nearest to people: women, others, children, men, students, those, person, americans,
# Nearest to d: b, c, f, typology, vitamin, goblin, piano, j,
# Nearest to on: from, upon, through, regarding, cutoff, across, off, about,
# Nearest to his: her, s, my, their, whose, your, its, our,
# Nearest to into: through, within, in, between, create, of, includes, from,
# Nearest to most: some, less, more, particularly, many, list, all, number,
# Nearest to known: such, referred, well, same, used, regarded, emerged, seen,
# Nearest to at: near, from, around, towards, embellished, zar, sampler, via,
# Nearest to had: has, having, have, were, yet, was, ve, kindling,
# Nearest to while: although, when, among, though, where, but, thus, however,
# Nearest to american: canadian, australian, professional, german, european, scottish, japanese, russian,
# Nearest to by: including, include, from, nootka, against, like, with, through,
# Average loss at step 82000: 3.130162
# Average loss at step 84000: 3.144568
# Average loss at step 86000: 3.132871
# Average loss at step 88000: 3.050389
# Average loss at step 90000: 3.046816
# Nearest to one: nine, seven, eight, six, five, monophysites, lancet, three,
# Nearest to see: tipu, elkhart, britannicus, provocation, topics, references, traumas, mounts,
# Nearest to new: old, flanagan, kuril, phylogenetic, weizenbaum, overfishing, endemic, tangled,
# Nearest to of: against, from, including, between, with, include, into, sai,
# Nearest to people: women, person, students, others, we, men, those, americans,
# Nearest to d: b, isbn, nine, january, february, september, april, july,
# Nearest to on: through, cutoff, off, onto, upon, from, regarding, across,
# Nearest to his: her, s, their, whose, my, your, its, him,
# Nearest to into: through, in, within, from, between, across, create, with,
# Nearest to most: some, many, less, more, number, particularly, highly, several,
# Nearest to known: such, referred, well, seen, regarded, same, served, described,
# Nearest to at: near, towards, from, around, embellished, until, boles, ramakrishna,
# Nearest to had: have, has, having, were, yet, radii, was, kindling,
# Nearest to while: although, thus, when, though, among, where, however, but,
# Nearest to american: canadian, british, australian, french, german, english, professional, scottish,
# Nearest to by: including, against, with, include, without, through, thus, nootka,
# Average loss at step 92000: 3.083063
# Average loss at step 94000: 3.127167
# Average loss at step 96000: 3.049627
# Average loss at step 98000: 3.040670
# Average loss at step 100000: 3.139515
# Nearest to one: seven, nine, six, two, five, isbn, eight, khan,
# Nearest to see: tipu, despatch, elkhart, schwenkfeld, references, provocation, hahn, garde,
# Nearest to new: old, kuril, overfishing, weizenbaum, earlier, kinsman, paradoxical, ffffff,
# Nearest to of: including, with, include, from, between, against, for, in,
# Nearest to people: women, men, nation, others, person, students, americans, children,
# Nearest to d: b, sgt, ekaterina, declarative, piano, deployable, forbes, tdma,
# Nearest to on: off, from, cutoff, along, onto, across, upon, regarding,
# Nearest to his: her, s, my, whose, their, your, its, him,
# Nearest to into: through, in, within, create, across, including, of, between,
# Nearest to most: many, more, some, number, less, particularly, several, list,
# Nearest to known: such, referred, seen, regarded, well, defined, described, same,
# Nearest to at: near, from, towards, around, burghs, during, reached, boles,
# Nearest to had: having, has, have, was, yet, were, radii, pentateuch,
# Nearest to while: although, though, when, however, among, where, by, thus,
# Nearest to american: australian, canadian, british, german, influential, scottish, professional, french,
# Nearest to by: including, include, with, while, without, through, against, alongside,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                       ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
